# %%
import random
import matplotlib.pyplot as plt

# %%
class Hello:
  def __init__(self):
    self.number_of_values = 500
  def __generator_2(self,number_of_values = 500):
    number_of_values = 500
    self.x = [random.uniform(0.,1.) for i in range(number_of_values)]
    return self.x
    
  def y_co_ordinate_generator(self):
    self.__generator_2()
    m  = max(self.x)-min(self.x)
    c = min(self.x)
    self.y = [m * self.x[i] + c for i in range(len(self.x))]
    self.generator_4()
    self.generator_2()
    return self.y
  def generator_4(self,peak_value = True):
    value = {'base':0.5, 'delta': 0.005}
    self.peak = []
    self.position = []
    for i in range(1,self.number_of_values-1):
      if self.y[i-1] < self.y[i] and self.y[i] > self.y[i+1]:
        self.peak.append(self.y[i])
        self.position.append(i)
    return self.peak,self.position
  def generator_2(self):
    self.squiggles_y_data = [x + random.randint(-5,5) / 500 for x in Y]
    return self.squiggles_y_data

# %%
hello  = Hello()
hello.y_co_ordinate_generator()
X = hello.x
Y  = hello.y
position = hello.position
peak = hello.peak
squiggles = hello.squiggles_y_data

# %%
plt.figure(figsize = (20,6))
plt.grid(True,color = "black",linestyle = ":")
plt.title("Temprature vs Time Graph",fontsize = 20)
plt.xlabel("Time",fontsize = 15)
plt.ylabel("Temprature",fontsize = 15)
plt.ylim(-0.5,1.5)
plt.scatter(position,peak,s = 100, c = "red")
plt.plot(Y,color  = "g")
#plt.plot(squiggles,color  = "b")
plt.legend(["with out squiggles","Peak points"],fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (20,6))
plt.grid(True,color = "black",linestyle = ":")
plt.title("Temprature vs Time Graph  with squiggles",fontsize = 20)
plt.xlabel("Time",fontsize = 15)
plt.ylabel("Temprature",fontsize = 15)
plt.ylim(-0.5,1.5)
plt.plot(squiggles,color  = "b")
plt.legend(["with squiggles"],fontsize  =  15)
plt.show()

# %%
plt.figure(figsize = (20,6))
plt.grid(True,color = "black",linestyle = ":")
plt.title("Temprature vs Time Graph  with squiggles  and without squiggles",fontsize = 20)
plt.xlabel("Time",fontsize = 15)
plt.ylabel("Temprature",fontsize = 15)
plt.ylim(-0.5,1.5)
plt.plot(Y,color  = "g")
plt.scatter(position,peak,s = 100, c = "red")
plt.plot(squiggles,color  = "b")
plt.legend(["with out squiggles","with squiggles","Peak points"],fontsize  =  15)
plt.show()
