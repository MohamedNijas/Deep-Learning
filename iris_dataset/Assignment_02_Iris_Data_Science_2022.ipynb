# %% [markdown]
# # Assignment 02
#
# Dear Team Members,
#
# I hope you are doing GREAT!
#
# The following assignment is a step-by-step process to implement a multiclass classification using Iris classical dataset.
# The idea of the current assignment is to intensify what we have learned in deep learning.
#
# There are some new concepts and challenges that we will face in the current assignment, and we need to resolve each issue and move to the next step.
#
# In week 08 (lecture session), we will discuss part of the potential challenges. The assignment is easy to follow yet needs the patience to solve each question at a time.
#
# **Note:**
#
# Please note that every question has 0.5 and it provides five out of total ten marks for the assignment.
#
# The video presentation, as you have done for Assignment 01, provides the rest of the mark, which is 5.
#
# In short, 5 for coding + 5 for the video presentation = 10.

# %%
import pandas as pd
import numpy as np
import tensorflow
from tensorflow import keras
from tensorflow.keras.utils import  to_categorical
from keras import models,layers
from keras.models import Sequential
from keras.layers import  Dense,Flatten,Activation

# %%
#00 The iris.csv file (Iris dataset) is located in the Assignment folder below the current ipynb file.

# %% [markdown]
#  **Important Note:** We are NOT allowed to import the dataset from Keras. We need to upload the provided iris.csv file to colab from our Google Drive.

# %%
#00 1st, upload the iris.csv into your Google Drive (your Colab folder).

# %%
#01-a Find the path of iris.csv file, and save it in a variable called fileName.

# %%
fileName ="/content/drive/MyDrive/iris assignment/iris.csv"

# %%
#01-b Read the content of the iris.csv file and save it in a variable, named iris.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
iris = pd.read_csv(fileName)

# %%
#01-c Show the first 5 rows of the dataframe.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# As you see, the last column contains strings. We want to convert these strings to integers,  and we can work with them easily in our Neural Network model.
#
# setosa -> 0
#
# versicolor -> 1
#
# virginica -> 2

# %%
#2-a Please convert the last column strings to integers, as 
# setosa -> 0
# versicolor -> 1
# virginica -> 2

# %%
iris['species'] = iris["species"].replace(to_replace = "setosa",value = 0)
iris['species']  = iris["species"].replace(to_replace  = "versicolor",value = 1)
iris["species"]  = iris["species"].replace(to_replace = "virginica",value = 2)

# %%
#2-b Now, check the first 5 elements of the iris dataset once again:

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#03-a Select the first four columns of the dataframe as the Data and call the data x.

# %%
x = iris.drop(["species"],axis = 1)

# %%
#03-b Select the last column as the label and call it y.

# %%
y = iris["species"]

# %%
#04 Now, it is the time to split the data (x) and the label (y) into training and testin segments, 
#   and call them parts x_train,x_test,y_train,y_test.

# %%
#04-a Please split the data, and label ito training and testing segments, while the size of test data is 20%,
#     and use randome_state = 123 to make all the answers similar in the whole class.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test  = train_test_split(x,y,test_size= 0.2,random_state  = 123)

# %%
#04-b Please, check the first five rows of  x_train,x_test,y_train,y_test.

# %%
x_train.head(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 130           7.4          2.8           6.1          1.9
# 119           6.0          2.2           5.0          1.5
# 29            4.7          3.2           1.6          0.2
# 0             5.1          3.5           1.4          0.2
# 62            6.0          2.2           4.0          1.0

# %%
x_test.head(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 72            6.3          2.5           4.9          1.5
# 112           6.8          3.0           5.5          2.1
# 132           6.4          2.8           5.6          2.2
# 88            5.6          3.0           4.1          1.3
# 37            4.9          3.1           1.5          0.1

# %%
y_train.head(5)
# Out:
# 130    2
# 119    2
# 29     0
# 0      0
# 62     1
# Name: species, dtype: int64

# %%
y_test.head(5)
# Out:
# 72     1
# 112    2
# 132    2
# 88     1
# 37     0
# Name: species, dtype: int64

# %%
#04-c Check the length of the x_train and x_test. If the numbers are 120 & 30, AWESOME! 
#     You are good to continue!

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
#05-a Please, convert y_train and y_test into categorical, and call them
#     one_hot_train_labels, and one_hot_test_labels, respectively.

# %%
one_hot_train_labels = to_categorical(y_train)
one_hot_test_labels = to_categorical(y_test)

# %%
#06-a Please define a sequential model that contains 3 dense layers.
#     In the first and second layers, use 100 hidden units (neurons) and a 'relu' activation function.
#     For the last layer, we need to use 3 as the number of output, 
#     and the reason is we have three classes (setosa -> 0, versicolor -> 1, virginica -> 2)
#     Also, please pick an appropriate activation function for the last layer. 
#     (You already have guessed what could be the best when we have converted the labels to categorical.)

# %%
 layer_set_1= keras.Sequential([
     keras.layers.Dense(100,input_shape = (4,),activation = "relu"),
     keras.layers.Dense(100,activation = "relu"),
     keras.layers.Dense(3,activation = "softmax")

 ])

# %%
#06-b Now, please compile your model using 'rmsprop', an appropriate loss function, and 'accuracy' for your metrics.

# %%
layer_set_1.compile(
    optimizer  =  'rmsprop',
    loss =  "categorical_crossentropy",
    metrics = ["accuracy"])

# %%
#07-a Pleease fit your model using epoch=20, batch = 10.

# %%
layer_set_1.fit(x_train,one_hot_train_labels,epochs = 20,batch_size = 10)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 2ms/step - loss: 0.8036 - accuracy: 0.7000
# Epoch 2/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5686 - accuracy: 0.8333
# Epoch 3/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.8750
# Epoch 4/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.9167
# Epoch 5/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.9333
# Epoch 6/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.9083
# Epoch 7/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.9333
# Epoch 8/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2337 - accuracy: 0.9583
# Epoch 9/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9500
# Epoch 10/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2050 - accuracy: 0.9333
# Epoch 11/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9500
# Epoch 12/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9500
# Epoch 13/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1570 - accuracy: 0.9667
# Epoch 14/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1555 - accuracy: 0.9583
# Epoch 15/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1353 - accuracy: 0.9750
# Epoch 16/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9750
# Epoch 17/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9667
# Epoch 18/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9500
# Epoch 19/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1179 - accuracy: 0.9500
# Epoch 20/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9667

# %%
#08-a Please calculate the result, evaluating your x_test, one_hot_test_label, and see how accurate your model works.

# %%
layer_set_1.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 142ms/step - loss: 0.1253 - accuracy: 0.9667
# [0.12534227967262268, 0.9666666388511658]

# %%
#09-a Now, we repeate all we have done in #06-a with the following parameters:
#     In the first and second layers, use 10 hidden units (neurons) and a 'relu' activation function.
#     For the last layer, we need to use 3.

# %%
layer_set_2  = keras.Sequential([
                          keras.layers.Dense(10,input_shape = (4,),activation = "relu"),
                          keras.layers.Dense(10,activation = "relu"),
                          keras.layers.Dense(3,activation = "softmax")

])

# %%
#09-b Use the same setting as you have done for #06-b (compile phase using 'rmsprom' and et cetera)

# %%
layer_set_2.compile(
    optimizer =  "rmsprop",
    loss =  "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
#09-c Please fit your model using epoch=4, batch = 10.

# %%
layer_set_2.fit(x_train,one_hot_train_labels,epochs = 4,batch_size = 10)
# Out:
# Epoch 1/4
# 12/12 [==============================] - 1s 2ms/step - loss: 1.1881 - accuracy: 0.3000
# Epoch 2/4
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1604 - accuracy: 0.2833
# Epoch 3/4
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1443 - accuracy: 0.2583
# Epoch 4/4
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1313 - accuracy: 0.0250

# %%
#09-d Please calculate the result, evaluating your x_test, one_hot_test_label, and see how accurate your model works.

# %%
layer_set_2.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 144ms/step - loss: 1.1135 - accuracy: 0.0000e+00
# [1.1135433912277222, 0.0]

# %%
#10-a Please explain all you have learned from this assignment. 
# Theese are some quiestions that you could answer:
# How the number of layers or hidden units could impact the accuracy of our model.
# Do we always suffer from overfitting?
# How can we find and manage overfitting?

# %% [markdown]
# when the number of layers and neuron in a layer increase the accuracy of the model increases.when we train the model for lower number of training datasets,less epochs we will face the overfitting issue but it does't happen always.when overfitting happens the accuracy for the train data is high but accuracy for the validation data is very.we can eliminate the overfitting by train the model using high amount of training data sets

# %%
#10-b
# Please try different sessing as we did in #09
# You can change the number of layers, hidden units, compile parameters, number of epochs, batch_size... everything!
# Please change one parameter at a time.
# And share your experience.

# %% [markdown]
# # TEST 01

# %%
layer_set_3 = keras.Sequential([
                            keras.layers.Dense(500,input_shape = (4,),activation = "relu"),
                            keras.layers.Dense(200,activation = "relu"),
                            keras.layers.Dense(150,activation  = "relu"),
                            keras.layers.Dense(3,activation = "softmax")
])

# %%
layer_set_3.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"],
)

# %%
layer_set_3.fit(x_train,one_hot_train_labels,epochs = 20,batch_size = 10)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 4ms/step - loss: 0.7915 - accuracy: 0.6333
# Epoch 2/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5122 - accuracy: 0.7917
# Epoch 3/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4191 - accuracy: 0.8000
# Epoch 4/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3515 - accuracy: 0.8417
# Epoch 5/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2903 - accuracy: 0.8667
# Epoch 6/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2433 - accuracy: 0.9167
# Epoch 7/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9333
# Epoch 8/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2184 - accuracy: 0.9333
# Epoch 9/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9583
# Epoch 10/20
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2542 - accuracy: 0.8917
# Epoch 11/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1157 - accuracy: 0.9583
# Epoch 12/20
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1555 - accuracy: 0.9417
# Epoch 13/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2049 - accuracy: 0.9083
# Epoch 14/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1461 - accuracy: 0.9583
# Epoch 15/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1277 - accuracy: 0.9417
# Epoch 16/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9583
# Epoch 17/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1160 - accuracy: 0.9500
# Epoch 18/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1689 - accuracy: 0.9417
# Epoch 19/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.9750
# Epoch 20/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1205 - accuracy: 0.9500

# %%
layer_set_3.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 150ms/step - loss: 0.1259 - accuracy: 0.9667
# [0.12587061524391174, 0.9666666388511658]

# %% [markdown]
# ## From above  experiment **TEST 1** ,When increases the **number of hidden layers the accuracy does not change** for validation data for this data set

# %% [markdown]
# # TEST 02

# %%
layer_set_3 = keras.Sequential([
                            keras.layers.Dense(500,input_shape = (4,),activation = "relu"),
                            keras.layers.Dense(200,activation = "relu"),
                            keras.layers.Dense(150,activation  = "relu"),
                            keras.layers.Dense(3,activation = "softmax")
])

# %%
layer_set_3.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"],
)

# %%
layer_set_3.fit(x_train,one_hot_train_labels,epochs = 20,batch_size = 2)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7107 - accuracy: 0.6417
# Epoch 2/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3380 - accuracy: 0.8583
# Epoch 3/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2602 - accuracy: 0.9000
# Epoch 4/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2176 - accuracy: 0.8917
# Epoch 5/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1743 - accuracy: 0.9333
# Epoch 6/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1879 - accuracy: 0.9333
# Epoch 7/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2173 - accuracy: 0.9083
# Epoch 8/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1767 - accuracy: 0.9167
# Epoch 9/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1498 - accuracy: 0.9250
# Epoch 10/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9333
# Epoch 11/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1671 - accuracy: 0.9417
# Epoch 12/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1927 - accuracy: 0.9333
# Epoch 13/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9500
# Epoch 14/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2146 - accuracy: 0.9417
# Epoch 15/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1745 - accuracy: 0.9500
# Epoch 16/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9583
# Epoch 17/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9833
# Epoch 18/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1051 - accuracy: 0.9667
# Epoch 19/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9417
# Epoch 20/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 0.9750

# %%
layer_set_3.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 139ms/step - loss: 1.7841 - accuracy: 0.7333
# [1.784053921699524, 0.7333333492279053]

# %% [markdown]
# ## From above  **TEST 2** when **reduces the batch  size** the **accuracy for the validation data increases**

# %% [markdown]
# # TEST 03

# %%
layer_set_3 = keras.Sequential([
                            keras.layers.Dense(500,input_shape = (4,),activation = "relu"),
                            keras.layers.Dense(200,activation = "relu"),
                            keras.layers.Dense(150,activation  = "relu"),
                            keras.layers.Dense(3,activation = "softmax")
])

# %%
layer_set_3.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"],
)

# %%
layer_set_3.fit(x_train,one_hot_train_labels,epochs = 5,batch_size = 10)
# Out:
# Epoch 1/5
# 12/12 [==============================] - 1s 4ms/step - loss: 0.7596 - accuracy: 0.6583
# Epoch 2/5
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4660 - accuracy: 0.7250
# Epoch 3/5
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3425 - accuracy: 0.8500
# Epoch 4/5
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3554 - accuracy: 0.8000
# Epoch 5/5
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2162 - accuracy: 0.9417

# %%
layer_set_3.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 156ms/step - loss: 0.3588 - accuracy: 0.7667
# [0.3587874472141266, 0.7666666507720947]

# %% [markdown]
# ## From above  **TEST 3**, when reduces the **number of epochs** accuracy for test data reduces.Accuracy reduces for validation data

# %% [markdown]
# # TEST 04

# %%
layer_set_3 = keras.Sequential([
                            keras.layers.Dense(500,input_shape = (4,),activation = "relu"),
                            keras.layers.Dense(200,activation = "relu"),
                            keras.layers.Dense(150,activation  = "relu"),
                            keras.layers.Dense(3,activation = "softmax")
])

# %%
layer_set_3.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"],
)

# %%
layer_set_3.compile(
    optimizer = "adam",
    loss  = "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
layer_set_3.fit(x_train,one_hot_train_labels,epochs = 20,batch_size = 10)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8531 - accuracy: 0.5750
# Epoch 2/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5198 - accuracy: 0.7167
# Epoch 3/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3297 - accuracy: 0.9417
# Epoch 4/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3287 - accuracy: 0.8167
# Epoch 5/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9417
# Epoch 6/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1683 - accuracy: 0.9417
# Epoch 7/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9750
# Epoch 8/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 0.9667
# Epoch 9/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.9500
# Epoch 10/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1054 - accuracy: 0.9583
# Epoch 11/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9667
# Epoch 12/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9667
# Epoch 13/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9750
# Epoch 14/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0880 - accuracy: 0.9750
# Epoch 15/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9833
# Epoch 16/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0970 - accuracy: 0.9500
# Epoch 17/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 0.9667
# Epoch 18/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9750
# Epoch 19/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3062 - accuracy: 0.8917
# Epoch 20/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.9167

# %%
layer_set_3.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 141ms/step - loss: 0.2009 - accuracy: 0.8667
# [0.20091195404529572, 0.8666666746139526]

# %% [markdown]
# ## From above  **TEST 4** When we **change the optimizer from  rmsprop  to adam** there is **REDUCES in accuracy** for validation data

# %% [markdown]
# # TEST 05

# %%
layer_set_4 = keras.Sequential([
                            keras.layers.Dense(150,input_shape = (4,),activation = "relu"),
                            keras.layers.Dense(100,activation = "relu"),
                            keras.layers.Dense(25,activation  = "relu"),
                            keras.layers.Dense(3,activation = "softmax")
])

# %%
layer_set_4.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"],
)

# %%
layer_set_4.fit(x_train,one_hot_train_labels,epochs = 20,batch_size = 10)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 2ms/step - loss: 0.9137 - accuracy: 0.5417
# Epoch 2/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.6917
# Epoch 3/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5169 - accuracy: 0.7833
# Epoch 4/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.7667
# Epoch 5/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8583
# Epoch 6/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3658 - accuracy: 0.8917
# Epoch 7/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8500
# Epoch 8/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2776 - accuracy: 0.9583
# Epoch 9/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2988 - accuracy: 0.8917
# Epoch 10/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8917
# Epoch 11/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.9000
# Epoch 12/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2048 - accuracy: 0.9500
# Epoch 13/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1969 - accuracy: 0.9417
# Epoch 14/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9167
# Epoch 15/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1714 - accuracy: 0.9583
# Epoch 16/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1794 - accuracy: 0.9333
# Epoch 17/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9500
# Epoch 18/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9417
# Epoch 19/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1644 - accuracy: 0.9417
# Epoch 20/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9667

# %%
layer_set_4.evaluate(x_test,one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 130ms/step - loss: 0.1441 - accuracy: 0.9667
# [0.14411035180091858, 0.9666666388511658]

# %% [markdown]
# ## From above  experiment **TEST 5**,When we **reduces the neurons** in   the hidden layer the **accuracy for validation data INCREASES** FOR THIS DATA SET

# %% [markdown]
# ---
# # Deliverables:
# 1. Please, submit the current ipynb file with your responses.
# 2. Please, record and upload to YouTube a 5 to 10 minutes video recorded clip, describing all you have done. If you go beyond 10 minutes, it is fine. The mentioned time range is to show how the scale of the assignment could be.
# Then submit the link to the uploaded YouTube video in the **Text Submision section** (see image below).
#
# ![image.png](https://i.ibb.co/gjW5wYC/bb-submission-instructions.png)

# %% [markdown]
# **Summary:**
#
# In short, what we need to submit are:
#
# a)	The current **ipynb file** that contains all the code (5 marks).
#
# b)	The **YouTube link** of your recorded video in the **Text Submission section** (5 marks).

# %% [markdown]
# Wish you only the best, Dear Team Members!
#
# Reza
